# %%
l = ["my name is sushmita", "my name is sushmita"]

# %%
import pandas as pd

# %%
df = pd.DataFrame({"name":l})

# %%
df
# Out:
#                   name
# 0  my name is sushmita
# 1  my name is sushmita

# %%
from sklearn.feature_extraction.text import CountVectorizer

# %%
cv = CountVectorizer()

# %%
# new_data = cv.fit_transform(df['name'])
new_data = cv.fit_transform(df['name']).toarray()

# %%
new_data
# Out:
# array([[1, 1, 1, 1],
#        [1, 1, 1, 1]], dtype=int64)
